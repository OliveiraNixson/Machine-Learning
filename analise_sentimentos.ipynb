# %%
#lendo os arquivos
import pandas as pd

yelp = pd.read_csv('/content/yelp_labelled.txt',sep='\t',names=['texto', 'sentimento'])
amazon = pd.read_csv('/content/amazon_cells_labelled.txt',sep='\t',names=['texto', 'sentimento'])
imdb = pd.read_csv('/content/imdb_labelled.txt',sep='\t',names=['texto', 'sentimento'])

data =pd.concat([ amazon,imdb,yelp],ignore_index=True)

data.sample(5)
# Out:
#                                                   texto  sentimento
# 167   The look of it is very sharp and the screen is...           1
# 1157  I must say I have taped most of the episodes a...           1
# 1543  It has a very good plot, it holds your complet...           1
# 1724  Just consider the excellent story, solid actin...           1
# 2538  When I received my Pita it was huge it did hav...           1

# %%
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
#Fazendo a limpeza dos dados
import re
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
nltk.download('punkt_tab')

from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer


stopwords = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def limpar_textos(text):
  texto = text.lower()

  texto = re.sub(r'\d+','',text)

  texto = re.sub(r'[^\w\s]','',text)

  texto = re.sub(r'\s+',' ',text).strip()

  words = nltk.word_tokenize(text)

  words = [lemmatizer.lemmatize(word) for word in words if word not in stopwords]


  return ''.join(words)

data['texto'] = data['texto'].apply(limpar_textos)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %%
#Fazendo a partição dos dados
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer



X = data['texto']
y = data['sentimento']
Xtrain,Xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2,random_state=38)

vectorizer = TfidfVectorizer()
Xtrain_trans = vectorizer.fit_transform(Xtrain)
Xtest_trans = vectorizer.transform(Xtest)

print(Xtrain_trans.shape)
print(Xtest_trans.shape)
# Out:
# (2198, 4074)
# (550, 4074)

# %%
#Criando um pipeline para facilitar a analise
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB

pipeline = Pipeline([
    ('vectorizer', TfidfVectorizer()),
    ('classifier', MultinomialNB())
])
print('Sucesso')
# Out:
# Sucesso

# %%
#Treinando o Modelo

pipeline.fit(Xtrain,ytrain)
print('Modelo Naive bayes')
# Out:
# Modelo Naive bayes

# %%
#Resultados do nosso modelo

from sklearn.metrics import accuracy_score

y_prev = pipeline.predict(Xtest)

accuracy = accuracy_score(ytest,y_prev)

print(f'A acurácia do modelo é {accuracy}')
# Out:
# A acurácia do modelo é 0.5272727272727272

# %% [markdown]
# Devido a fatores relacionados ao sono vou para por aqui :)
